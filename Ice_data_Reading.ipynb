# %%
import netCDF4
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import matplotlib.pyplot as plt
from cartopy.io.img_tiles import Stamen, GoogleTiles
import xarray as xr
import os

# %%
# Combining data to have 10 years

#pr
huss1 = xr.open_dataset(r'C:\Users\Lee\Desktop\Data\huss_day_CNRM-CM5_rcp45_r1i1p1_20210101-20251231.nc')  # 2021-2025
huss2 = xr.open_dataset(r'C:\Users\Lee\Desktop\Data\huss_day_CNRM-CM5_rcp45_r1i1p1_20260101-20301231.nc')  # 2026-2030

# Concatenate along the 'time' dimension
huss_data = xr.concat([huss1, huss2], dim='time')

# Define the path to the 'data' folder on Desktop and use os.path.join for correct formatting
output_path = os.path.join(os.path.expanduser('~'), 'Desktop', 'Data', 'huss_data.nc')

# Save the combined dataset to this folder
huss_data.to_netcdf(output_path)

#pr
pr1 = xr.open_dataset(r'C:\Users\Lee\Desktop\Data\pr_day_CNRM-CM5_rcp45_r1i1p1_20210101-20251231.nc')  # 2021-2025
pr2 = xr.open_dataset(r'C:\Users\Lee\Desktop\Data\pr_day_CNRM-CM5_rcp45_r1i1p1_20260101-20301231.nc')  # 2026-2030

# Concatenate along the 'time' dimension
pr_data = xr.concat([pr1, pr2], dim='time')

# Define the path to the 'data' folder on Desktop and use os.path.join for correct formatting
output_path = os.path.join(os.path.expanduser('~'), 'Desktop', 'Data', 'pr_data.nc')

# Save the combined dataset to this folder
pr_data.to_netcdf(output_path)

#rlds
rlds1 = xr.open_dataset(r'C:\Users\Lee\Desktop\Data\rlds_day_CNRM-CM5_rcp45_r1i1p1_20210101-20251231.nc')  # 2021-2025
rlds2 = xr.open_dataset(r'C:\Users\Lee\Desktop\Data\rlds_day_CNRM-CM5_rcp45_r1i1p1_20260101-20301231.nc')  # 2026-2030

# Concatenate along the 'time' dimension
rlds_data = xr.concat([rlds1, rlds2], dim='time')

# Define the path to the 'data' folder on Desktop and use os.path.join for correct formatting
output_path = os.path.join(os.path.expanduser('~'), 'Desktop', 'Data', 'rlds_data.nc')

# Save the combined dataset to this folder
rlds_data.to_netcdf(output_path)

#rsds
rsds1 = xr.open_dataset(r'C:\Users\Lee\Desktop\Data\rsds_day_CNRM-CM5_rcp45_r1i1p1_20210101-20251231.nc')  # 2021-2025
rsds2 = xr.open_dataset(r'C:\Users\Lee\Desktop\Data\rsds_day_CNRM-CM5_rcp45_r1i1p1_20260101-20301231.nc')  # 2026-2030

# Concatenate along the 'time' dimension
rsds_data = xr.concat([rsds1, rsds2], dim='time')

# Define the path to the 'data' folder on Desktop and use os.path.join for correct formatting
output_path = os.path.join(os.path.expanduser('~'), 'Desktop', 'Data', 'rsds_data.nc')

# Save the combined dataset to this folder
rsds_data.to_netcdf(output_path)

#tas
tas1 = xr.open_dataset(r'C:\Users\Lee\Desktop\Data\tas_day_CNRM-CM5_rcp45_r1i1p1_20210101-20251231.nc')  # 2021-2025
tas2 = xr.open_dataset(r'C:\Users\Lee\Desktop\Data\tas_day_CNRM-CM5_rcp45_r1i1p1_20260101-20301231.nc')  # 2026-2030

# Concatenate along the 'time' dimension
tas_data = xr.concat([tas1, tas2], dim='time')

# Define the path to the 'data' folder on Desktop and use os.path.join for correct formatting
output_path = os.path.join(os.path.expanduser('~'), 'Desktop', 'Data', 'tas_data.nc')

# Save the combined dataset to this folder
tas_data.to_netcdf(output_path)

#uas
uas1 = xr.open_dataset(r'C:\Users\Lee\Desktop\Data\uas_day_CNRM-CM5_rcp45_r1i1p1_20210101-20251231.nc')  # 2021-2025
uas2 = xr.open_dataset(r'C:\Users\Lee\Desktop\Data\uas_day_CNRM-CM5_rcp45_r1i1p1_20260101-20301231.nc')  # 2026-2030

# Concatenate along the 'time' dimension
uas_data = xr.concat([uas1, uas2], dim='time')

# Define the path to the 'data' folder on Desktop and use os.path.join for correct formatting
output_path = os.path.join(os.path.expanduser('~'), 'Desktop', 'Data', 'uas_data.nc')

# Save the combined dataset to this folder
uas_data.to_netcdf(output_path)

#vas
vas1 = xr.open_dataset(r'C:\Users\Lee\Desktop\Data\vas_day_CNRM-CM5_rcp45_r1i1p1_20210101-20251231.nc')  # 2021-2025
vas2 = xr.open_dataset(r'C:\Users\Lee\Desktop\Data\vas_day_CNRM-CM5_rcp45_r1i1p1_20260101-20301231.nc')  # 2026-2030

# Concatenate along the 'time' dimension
vas_data = xr.concat([vas1, vas2], dim='time')

# Define the path to the 'data' folder on Desktop and use os.path.join for correct formatting
output_path = os.path.join(os.path.expanduser('~'), 'Desktop', 'Data', 'vas_data.nc')

# Save the combined dataset to this folder
vas_data.to_netcdf(output_path)

#mlotst
mlotst1 = xr.open_dataset(r'C:\Users\Lee\Desktop\Data\mlotst_Omon_CNRM-CM5_rcp45_r1i1p1_201601-202512.nc')  # 2021-2025
mlotst2 = xr.open_dataset(r'C:\Users\Lee\Desktop\Data\mlotst_Omon_CNRM-CM5_rcp45_r1i1p1_201601-202512.nc')  # 2026-2030

# Concatenate along the 'time' dimension
mlotst_data = xr.concat([mlotst1, mlotst2], dim='time')

# Define the path to the 'data' folder on Desktop and use os.path.join for correct formatting
output_path = os.path.join(os.path.expanduser('~'), 'Desktop', 'Data', 'mlotst_data.nc')

# Save the combined dataset to this folder
mlotst_data.to_netcdf(output_path)

#uo
uo1 = xr.open_dataset(r'C:\Users\Lee\Desktop\Data\uo_Omon_CNRM-CM5_rcp45_r1i1p1_201601-202512.nc')  # 2021-2025
uo2 = xr.open_dataset(r'C:\Users\Lee\Desktop\Data\uo_Omon_CNRM-CM5_rcp45_r1i1p1_201601-202512.nc')  # 2026-2030

# Concatenate along the 'time' dimension
uo_data = xr.concat([uo1, uo2], dim='time')

# Define the path to the 'data' folder on Desktop and use os.path.join for correct formatting
output_path = os.path.join(os.path.expanduser('~'), 'Desktop', 'Data', 'uo_data.nc')

# Save the combined dataset to this folder
uo_data.to_netcdf(output_path)

#sos
sos1 = xr.open_dataset(r'C:\Users\Lee\Desktop\Data\sos_Omon_CNRM-CM5_rcp45_r1i1p1_201601-202512.nc')  # 2021-2025
sos2 = xr.open_dataset(r'C:\Users\Lee\Desktop\Data\sos_Omon_CNRM-CM5_rcp45_r1i1p1_201601-202512.nc')  # 2026-2030

# Concatenate along the 'time' dimension
sos_data = xr.concat([sos1, sos2], dim='time')

# Define the path to the 'data' folder on Desktop and use os.path.join for correct formatting
output_path = os.path.join(os.path.expanduser('~'), 'Desktop', 'Data', 'sos_data.nc')

# Save the combined dataset to this folder
sos_data.to_netcdf(output_path)

#tos
tos1 = xr.open_dataset(r'C:\Users\Lee\Desktop\Data\tos_Omon_CNRM-CM5_rcp45_r1i1p1_201601-202512.nc')  # 2021-2025
tos2 = xr.open_dataset(r'C:\Users\Lee\Desktop\Data\tos_Omon_CNRM-CM5_rcp45_r1i1p1_201601-202512.nc')  # 2026-2030

# Concatenate along the 'time' dimension
tos_data = xr.concat([tos1, tos2], dim='time')

# Define the path to the 'data' folder on Desktop and use os.path.join for correct formatting
output_path = os.path.join(os.path.expanduser('~'), 'Desktop', 'Data', 'tos_data.nc')

# Save the combined dataset to this folder
tos_data.to_netcdf(output_path)

#vo
vo1 = xr.open_dataset(r'C:\Users\Lee\Desktop\Data\vo_Omon_CNRM-CM5_rcp45_r1i1p1_201601-202512.nc')  # 2021-2025
vo2 = xr.open_dataset(r'C:\Users\Lee\Desktop\Data\vo_Omon_CNRM-CM5_rcp45_r1i1p1_201601-202512.nc')  # 2026-2030

# Concatenate along the 'time' dimension
vo_data = xr.concat([vo1, vo2], dim='time')

# Define the path to the 'data' folder on Desktop and use os.path.join for correct formatting
output_path = os.path.join(os.path.expanduser('~'), 'Desktop', 'Data', 'vo_data.nc')

# Save the combined dataset to this folder
vo_data.to_netcdf(output_path)

# %%
# Pre's from Vargas New_Data
def day_to_hour(day):
    start = datetime(2021, 1, 1, 1, 0, 0)
    return int((day - start).total_seconds() // 3600)

def get_days(ds):
    start = datetime(2006, 1, 1)
    min_date = datetime(2021, 1, 1, 0, 0, 0)
    max_date = datetime(2031, 1, 1, 0, 0, 0)
    times = [start + timedelta(days=d) for d in ds['time'][:]]
    times = list(filter(lambda d: min_date <= d < max_date, times))
    return times

def interp_years(data, ds, years):
    days = get_days(ds)
    xp = np.array([day_to_hour(day) for day in days])
    x = np.arange(1, years * 365 * 24 + 1)
    f = np.interp(x, xp, data)
    return f

def get_atm_forcing(path, s, lat_ind, lon_ind):
    key = path.split('_')[0] 
    print(f'{key}')
    key = key.split('\\')[-1] # Change 1
    key = key.split('/')[-1]
    print(f'{key}')
    ds = netCDF4.Dataset(path)
    lat = ds.variables['lat'][:].data[lat_ind]
    lon = ds.variables['lon'][:].data[lon_ind]
    _forcing = ds.variables[key][s, lat_ind, lon_ind].data
    forcing = interp_years(_forcing, ds, 10)
    fig = plt.figure(figsize=(12, 6))
    ax = fig.add_subplot(121)
    ax.plot(forcing)
    ax.set_title(key)
    ax = fig.add_subplot(122)
    ax.plot(_forcing)
    ax.set_title(key)
    print(f'{key} : {ds.variables[key].units}')
    # forcing = forcing.round(5)
    ds.close()
    return key, forcing, lat, lon

def make_atm_forcing(paths, lat_ind, lon_ind):
    # Slice two years 2016-2020
    s = slice(0, 365 * 10 + 4)
    atm = {}
    for path in paths:
        key, forcing, lat, lon = get_atm_forcing(path, s, lat_ind, lon_ind)
        atm[key] = forcing
    # print(atm['rsds'])
    df = pd.DataFrame(atm, columns=list(atm.keys()))
    df.to_csv(f'atm_{lat:.0f}_{lon:.0f}_10years.txt', sep=' ', header=None, index=False, float_format='%.6f')
    return df

def get_ocn_forcing(path, s, ind1, ind2):
    key = path.split('_')[0]
    key = key.split('\\')[-1]  # Handle Windows paths
    key = key.split('/')[-1]  # Handle Unix paths
    with netCDF4.Dataset(path) as ds:
        # Extract latitude and longitude
        lat = ds.variables['lat'][:].data[ind1, ind2]
        lon = ds.variables['lon'][:].data[ind1, ind2]
        data = ds.variables[key][:].data

        # Check data dimensions
        if data.ndim == 4:
            forcing = data[s, 0, ind1, ind2]
        elif data.ndim == 3:
            forcing = data[s, ind1, ind2]
        else:
            raise ValueError(f"Unexpected data dimensions: {data.ndim}D")

        # Interpolate for 10 years
        forcing = interp_years(forcing, ds, 10)

        # Debugging
        print(f"Processed variable: {key}, Shape: {data.shape}")
        print(f"Original forcing data: {forcing[:20]} ... {forcing[-20:]}")

        # Plot
        fig = plt.figure()
        ax = fig.add_subplot(111)
        ax.plot(forcing)
        ax.set_title(key)
        print(f'{key} : {ds.variables[key].units}')
        return key, forcing, lat, lon


def make_ocn_forcing(paths, ind1, ind2):
    s = slice(0, 12*10)  # Adjust based on dataset time steps
    ocn = {}
    for path in paths:
        try:
            key, forcing, lat, lon = get_ocn_forcing(path, s, ind1, ind2)
            ocn[key] = forcing
        except Exception as e:
            print(f"Failed to process {path}: {e}")
    if ocn:
        df = pd.DataFrame(ocn, columns=list(ocn.keys()))
        df.to_csv(f'ocn_{lat:.0f}_{lon:.0f}_10years.txt', sep=' ', header=None, index=False,
                  float_format='%.6f')
        return df
    else:
        print("No data processed.")


def get_bgc_forcing(path, s, ind1, ind2):
    key = path.split('_')[0]
    key = key.split('\\')[-1]
    key = key.split("/")[-1]
    ds = netCDF4.Dataset(path)
    lat = ds.variables['lat'][:].data[ind1, ind2]
    lon = ds.variables['lon'][:].data[ind1, ind2]
    data = ds.variables[key][:].data
    if data.ndim == 4:
        forcing = data[s, 0 , ind1, ind2] * 1000
    else:
        forcing = data[s, ind1, ind2] * 1000
    print(f'{key} : {ds.variables[key].units}')
    fig = plt.figure()
    ax = fig.add_subplot(111)
    ax.plot(forcing)
    ax.set_title(key)
    # forcing = forcing.round(5)
    ds.close()
    return key, forcing, lat, lon

def make_bgc_forcing(paths, ind1, ind2):
    s = slice(0, 60)
    ocn = {}
    for path in paths:
        key, forcing, lat, lon = get_bgc_forcing(path, s, ind1, ind2)
        ocn[key] = forcing
    df = pd.DataFrame(ocn, columns=list(ocn.keys()))
    df.to_csv(f'bgc_{lat:.0f}_{lon:.0f}_5years.txt', sep=' ', header=None, index=False,
float_format='%.6f')
    return df

# %%
forcing = make_atm_forcing(
    paths=[
        r'C:\Users\Lee\Desktop\Data\rsds_data.nc',
        r'C:\Users\Lee\Desktop\Data\rlds_data.nc',
        r'C:\Users\Lee\Desktop\Data\uas_data.nc',
        r'C:\Users\Lee\Desktop\Data\vas_data.nc',
        r'C:\Users\Lee\Desktop\Data\tas_data.nc',
        r'C:\Users\Lee\Desktop\Data\huss_data.nc',
        r'C:\Users\Lee\Desktop\Data\pr_data.nc',
    ],
    lat_ind=123,
    lon_ind=247,
)
# Out:
# C:\Users\Lee\Desktop\Data\rsds
# rsds
# rsds : W m-2
# C:\Users\Lee\Desktop\Data\rlds
# rlds
# rlds : W m-2
# C:\Users\Lee\Desktop\Data\uas
# uas
# uas : m s-1
# C:\Users\Lee\Desktop\Data\vas
# vas
# vas : m s-1
# C:\Users\Lee\Desktop\Data\tas
# tas
# tas : K
# C:\Users\Lee\Desktop\Data\huss
# huss
# huss : 1
# C:\Users\Lee\Desktop\Data\pr
# pr
# pr : kg m-2 s-1

# %%
ocn_forcing = make_ocn_forcing(
    paths=[
        r'C:\Users\Lee\Desktop\Data\tos_data.nc',
        r'C:\Users\Lee\Desktop\Data\sos_data.nc',
        r'C:\Users\Lee\Desktop\Data\mlotst_data.nc',
        r'C:\Users\Lee\Desktop\Data\uo_data.nc',
        r'C:\Users\Lee\Desktop\Data\vo_data.nc',
    ],
    ind1=276,
    ind2=267,
)
# Out:
# Processed variable: tos, Shape: (240, 292, 362)
# Original forcing data: [271.45513916 271.45513916 271.45513916 271.45513916 271.45513916
#  271.45513916 271.45513916 271.45513916 271.45513916 271.45513916
#  271.45513916 271.45513916 271.45513916 271.45513916 271.45513916
#  271.45513916 271.45513916 271.45513916 271.45513916 271.45513916] ... [271.5055542 271.5055542 271.5055542 271.5055542 271.5055542 271.5055542
#  271.5055542 271.5055542 271.5055542 271.5055542 271.5055542 271.5055542
#  271.5055542 271.5055542 271.5055542 271.5055542 271.5055542 271.5055542
#  271.5055542 271.5055542]
# tos : K
# Processed variable: sos, Shape: (240, 292, 362)
# Original forcing data: [31.2836132 31.2836132 31.2836132 31.2836132 31.2836132 31.2836132
#  31.2836132 31.2836132 31.2836132 31.2836132 31.2836132 31.2836132
#  31.2836132 31.2836132 31.2836132 31.2836132 31.2836132 31.2836132
#  31.2836132 31.2836132] ... [30.2564621 30.2564621 30.2564621 30.2564621 30.2564621 30.2564621
# ...

# %%
# Create a figure and add an axes with a specified projection
fig, ax = plt.subplots(1, 1, figsize=(15, 6),
                       subplot_kw={'projection': ccrs.NorthPolarStereo()})

# Add a natural earth feature (like the bluemarble equivalent)
ax.stock_img()

# Plot the point (longitude, latitude)
ax.plot(348, 83, 'ro', transform=ccrs.Geodetic())

# Set the extent (bounding box) of the map in degrees (lon_min, lon_max, lat_min, lat_max)
ax.set_extent([-180, 180, 65, 90], ccrs.PlateCarree())

# Add coastlines and other features
ax.coastlines(resolution='110m')
ax.add_feature(cfeature.BORDERS, linestyle=':')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 12
#       9 ax.plot(348, 83, 'ro', transform=ccrs.Geodetic())
#      11 # Set the extent (bounding box) of the map in degrees (lon_min, lon_max, lat_min, lat_max)
# ---> 12 ax.set_extent([-180, 180, 65, 90], ccrs.PlateCarree())
#      14 # Add coastlines and other features
#      15 ax.coastlines(resolution='110m')
#
# File c:\Users\Lee\AppData\Local\Programs\Python\Python312\Lib\site-packages\cartopy\mpl\geoaxes.py:849, in GeoAxes.set_extent(self, extents, crs)
#     846         projected = boundary
#     848 if projected is None:
# --> 849     projected = self.projection.project_geometry(domain_in_crs, crs)
#     850 try:
#     851     # This might fail with an unhelpful error message ('need more
#     852     # than 0 values to unpack') if the specified extents fall outside
# ...
